# %%
import shutil
from ultralytics import YOLO

# !pip install ultralytics

dataset_path = '/content/drive/My Drive/GTSDB/data.yaml'

model = YOLO('yolov8n.pt')

model.train(data=dataset_path, epochs=300, patience=25)

source_path = '/content/runs'
destination_path = '/content/drive/My Drive/runs'

shutil.copytree(source_path, destination_path)
